# %%
#pip install numpy==1.18.5

# %%
#pip install opencv-python pillow scikit-image

# %% [markdown]
# Image location

# %% [markdown]
# ## # Location : https://mitu.co.in/dataset
# # Download all the imahg from / image folder and save in current working directory

# %% [markdown]
# Image loading using opencv

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img_cv = cv2.imread(r'D:\NLP\Day13\Computer_vision\images\lenna.png')

# %%
plt.imshow(img_cv)

# %%
import numpy
print (numpy.__version__)
# Out:
# 1.26.4

# %% [markdown]
# Image loading uusing set_matplotlib_close

# %%
import matplotlib.pyplot as plt

# %%
ing_plt = plt.imread(r'D:\NLP\Day13\Computer_vision\images\lenna.png')

# %%
plt.imshow(ing_plt)

# %%
#plt.imshow(img_cv)

# %% [markdown]
# Load image using skimage

# %%
from skimage import io

# %% [markdown]
# image laoding pillow

# %%
from PIL import Image

# %%
img_pil = Image.open(r'D:\NLP\Day13\Computer_vision\images\lenna.png')

# %%
plt.imshow(img_pil)

# %% [markdown]
# Image loading using tensorflow

# %%
import tensorflow as tf

# %%
img_tf = tf.io.read_file(r'D:\NLP\Day13\Computer_vision\images\lenna.png')
img_tf = tf.image.decode_image(img_tf, channels=3)

# %%
plt.imshow(img_tf)

# %%
type(image_cv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 type(image_cv)
#
# NameError: name 'image_cv' is not defined

# %%
type(img_pil)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
type(img_tf)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
ing_plt
# Out:
# array([[[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        [[0.8862745 , 0.5372549 , 0.49019608],
#         [0.8862745 , 0.5372549 , 0.49019608],
#         [0.8745098 , 0.5372549 , 0.52156866],
#         ...,
#         [0.9019608 , 0.5803922 , 0.47843137],
#         [0.8666667 , 0.50980395, 0.43137255],
#         [0.78431374, 0.3882353 , 0.3529412 ]],
#
#        ...,
#
#        [[0.32941177, 0.07058824, 0.23529412],
# ...

# %%
ing_plt.shape
# Out:
# (512, 512, 3)

# %%
r = ing_plt[:,:,0]
g = ing_plt[:,:,1]
b = ing_plt[:,:,2]

# %%
r.shape
# Out:
# (512, 512)

# %%
g.shape
# Out:
# (512, 512)

# %%
b.shape
# Out:
# (512, 512)

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.imshow(r, cmap='gray')
plt.subplot(132)
plt.imshow(g, cmap='gray')
plt.subplot(133)
plt.imshow(b, cmap='gray')

# %%
import  numpy as np

# %%
zeros = np.zeros([100, 100])

# %%
plt.imshow(zeros, cmap='gray')

# %%
zeros[56,89] = 0.5

# %%
plt.imshow(zeros, cmap='gray')

# %%
zeros[60] = 5
plt.imshow(zeros, cmap='gray')

# %%
np.random.randint(10,100)
# Out:
# 92

# %%
zeros = np.zeros([10000])

# %%
for i in range(10000):
    zeros[i] = np.random.randint(0, 255)

# %%
zeros = zeros.reshape(100,100)

# %%
plt.imshow(zeros, cmap='gray')

# %%
img_plt = plt.imread(r'D:\NLP\Day13\Computer_vision\images\images.png')

# %%
img_plt.shape
# Out:
# (194, 259, 4)

# %%
plt.imshow(img_plt)

# %%
img_plt.dtype
# Out:
# dtype('float32')

# %%
img_cv.dtype
# Out:
# dtype('uint8')

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
x_train.shape, x_train.shape
# Out:
# ((60000, 28, 28), (60000, 28, 28))

# %%
plt.imshow(x_train[1], cmap='gray')

# %% [markdown]
# RGB-BGR Channels

# %%
plt.subplot(121)
plt.imshow(ing_plt)
plt.subplot(122)
plt.imshow(img_cv)

# %%
cv2.imshow('My imgae', ing_plt)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_cv_new = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(121)
plt.imshow(ing_plt)
plt.subplot(122)
plt.imshow(img_cv_new)

# %%
import sys

# %%
sys.getsizeof(ing_plt)
# Out:
# 3145872

# %%
sys.getsizeof(img_cv_new)
# Out:
# 786576

# %%
img_cv_gray = cv2.imread('images/lena.png', 0)

# %%
img_cv_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_cv_gray, cmap='gray')
