# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten
from keras.preprocessing.image import ImageDataGenerator
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Build the CNN Model

# %%
def build_cnn(input_shape=(224,224,3), num_classes=10):
    
    model = Sequential()
    
    model.add(Conv2D(32, 3, activation='relu', input_shape=input_shape))
    model.add(MaxPool2D((2,2)))
    
    model.add(Conv2D(64, 3, activation='relu', input_shape=input_shape))
    model.add(MaxPool2D((2,2)))
    
    model.add(Flatten())
    
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
model = build_cnn(input_shape=(64,64,3))
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 31, 31, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 10)                125450
#
# =================================================================
# Total params: 144842 (565.79 KB)
# Trainable params: 144842 (565.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Create the ImageDataGenerator Object

# %%
train_datagen = ImageDataGenerator(rescale=1/255, 
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

# %%
train_dataset = train_datagen.flow_from_directory('ImageNet/train/',
                                          target_size=(64,64),
                                          batch_size=32,
                                          class_mode='categorical')
# Out:
# Found 5000 images belonging to 10 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1/255)

# %%
test_dataset = test_datagen.flow_from_directory('ImageNet/test/',
                                          target_size=(64,64),
                                          batch_size=32,
                                          class_mode='categorical')
# Out:
# Found 10000 images belonging to 1 classes.

# %%
train_dataset.class_indices
# Out:
# {'crocodile': 0,
#  'fish': 1,
#  'fossils': 2,
#  'frog': 3,
#  'insect': 4,
#  'reptiles': 5,
#  'scorpion': 6,
#  'snake': 7,
#  'spider': 8,
#  'toad': 9}

# %%
dict(train_dataset.class_indices)
# Out:
# {'crocodile': 0,
#  'fish': 1,
#  'fossils': 2,
#  'frog': 3,
#  'insect': 4,
#  'reptiles': 5,
#  'scorpion': 6,
#  'snake': 7,
#  'spider': 8,
#  'toad': 9}

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### Train the Model

# %%
model.fit(train_dataset,
          epochs=10,
          batch_size=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 157/157 [==============================] - 39s 216ms/step - loss: 1.9452 - accuracy: 0.2960
# Epoch 2/10
# 157/157 [==============================] - 15s 96ms/step - loss: 1.6808 - accuracy: 0.4208
# Epoch 3/10
# 157/157 [==============================] - 15s 95ms/step - loss: 1.5788 - accuracy: 0.4572
# Epoch 4/10
# 157/157 [==============================] - 15s 95ms/step - loss: 1.5095 - accuracy: 0.4782
# Epoch 5/10
# 157/157 [==============================] - 15s 95ms/step - loss: 1.4080 - accuracy: 0.5230
# Epoch 6/10
# 157/157 [==============================] - 15s 98ms/step - loss: 1.3440 - accuracy: 0.5414
# Epoch 7/10
# 157/157 [==============================] - 15s 97ms/step - loss: 1.3032 - accuracy: 0.5594
# Epoch 8/10
# 157/157 [==============================] - 15s 97ms/step - loss: 1.2388 - accuracy: 0.5882
# Epoch 9/10
# 157/157 [==============================] - 15s 97ms/step - loss: 1.2114 - accuracy: 0.5904
# Epoch 10/10
# 157/157 [==============================] - 15s 96ms/step - loss: 1.1958 - accuracy: 0.5996

# %% [markdown]
# ### Prediction on Unseen Data

# %%
import os
os.listdir('ImageNet/test/images')
# Out:
# ['test_0.JPEG',
#  'test_1.JPEG',
#  'test_10.JPEG',
#  'test_100.JPEG',
#  'test_1000.JPEG',
#  'test_1001.JPEG',
#  'test_1002.JPEG',
#  'test_1003.JPEG',
#  'test_1004.JPEG',
#  'test_1005.JPEG',
#  'test_1006.JPEG',
#  'test_1007.JPEG',
#  'test_1008.JPEG',
#  'test_1009.JPEG',
#  'test_101.JPEG',
#  'test_1010.JPEG',
#  'test_1011.JPEG',
#  'test_1012.JPEG',
#  'test_1013.JPEG',
#  'test_1014.JPEG',
#  'test_1015.JPEG',
#  'test_1016.JPEG',
#  'test_1017.JPEG',
#  'test_1018.JPEG',
#  'test_1019.JPEG',
#  'test_102.JPEG',
#  'test_1020.JPEG',
#  'test_1021.JPEG',
#  'test_1022.JPEG',
#  'test_1023.JPEG',
#  'test_1024.JPEG',
#  'test_1025.JPEG',
#  'test_1026.JPEG',
#  'test_1027.JPEG',
#  'test_1028.JPEG',
#  'test_1029.JPEG',
#  'test_103.JPEG',
#  'test_1030.JPEG',
#  'test_1031.JPEG',
#  'test_1032.JPEG',
#  'test_1033.JPEG',
#  'test_1034.JPEG',
#  'test_1035.JPEG',
#  'test_1036.JPEG',
#  'test_1037.JPEG',
#  'test_1038.JPEG',
#  'test_1039.JPEG',
#  'test_104.JPEG',
#  'test_1040.JPEG',
#  'test_1041.JPEG',
#  'test_1042.JPEG',
#  'test_1043.JPEG',
#  'test_1044.JPEG',
#  'test_1045.JPEG',
#  'test_1046.JPEG',
#  'test_1047.JPEG',
#  'test_1048.JPEG',
#  'test_1049.JPEG',
#  'test_105.JPEG',
#  'test_1050.JPEG',
#  'test_1051.JPEG',
#  'test_1052.JPEG',
#  'test_1053.JPEG',
#  'test_1054.JPEG',
#  'test_1055.JPEG',
#  'test_1056.JPEG',
#  'test_1057.JPEG',
#  'test_1058.JPEG',
#  'test_1059.JPEG',
#  'test_106.JPEG',
#  'test_1060.JPEG',
#  'test_1061.JPEG',
#  'test_1062.JPEG',
#  'test_1063.JPEG',
#  'test_1064.JPEG',
#  'test_1065.JPEG',
#  'test_1066.JPEG',
#  'test_1067.JPEG',
#  'test_1068.JPEG',
#  'test_1069.JPEG',
#  'test_107.JPEG',
#  'test_1070.JPEG',
#  'test_1071.JPEG',
#  'test_1072.JPEG',
#  'test_1073.JPEG',
#  'test_1074.JPEG',
#  'test_1075.JPEG',
#  'test_1076.JPEG',
#  'test_1077.JPEG',
#  'test_1078.JPEG',
#  'test_1079.JPEG',
#  'test_108.JPEG',
#  'test_1080.JPEG',
#  'test_1081.JPEG',
#  'test_1082.JPEG',
#  'test_1083.JPEG',
#  'test_1084.JPEG',
#  'test_1085.JPEG',
#  'test_1086.JPEG',
#  'test_1087.JPEG',
#  'test_1088.JPEG',
#  'test_1089.JPEG',
#  'test_109.JPEG',
#  'test_1090.JPEG',
#  'test_1091.JPEG',
#  'test_1092.JPEG',
#  'test_1093.JPEG',
#  'test_1094.JPEG',
#  'test_1095.JPEG',
#  'test_1096.JPEG',
#  'test_1097.JPEG',
#  'test_1098.JPEG',
#  'test_1099.JPEG',
#  'test_11.JPEG',
#  'test_110.JPEG',
#  'test_1100.JPEG',
#  'test_1101.JPEG',
#  'test_1102.JPEG',
#  'test_1103.JPEG',
#  'test_1104.JPEG',
#  'test_1105.JPEG',
#  'test_1106.JPEG',
#  'test_1107.JPEG',
#  'test_1108.JPEG',
#  'test_1109.JPEG',
#  'test_111.JPEG',
#  'test_1110.JPEG',
#  'test_1111.JPEG',
#  'test_1112.JPEG',
#  'test_1113.JPEG',
#  'test_1114.JPEG',
#  'test_1115.JPEG',
#  'test_1116.JPEG',
#  'test_1117.JPEG',
#  'test_1118.JPEG',
#  'test_1119.JPEG',
#  'test_112.JPEG',
#  'test_1120.JPEG',
#  'test_1121.JPEG',
#  'test_1122.JPEG',
#  'test_1123.JPEG',
#  'test_1124.JPEG',
#  'test_1125.JPEG',
#  'test_1126.JPEG',
#  'test_1127.JPEG',
#  'test_1128.JPEG',
#  'test_1129.JPEG',
#  'test_113.JPEG',
#  'test_1130.JPEG',
#  'test_1131.JPEG',
#  'test_1132.JPEG',
#  'test_1133.JPEG',
#  'test_1134.JPEG',
#  'test_1135.JPEG',
#  'test_1136.JPEG',
#  'test_1137.JPEG',
#  'test_1138.JPEG',
#  'test_1139.JPEG',
#  'test_114.JPEG',
#  'test_1140.JPEG',
#  'test_1141.JPEG',
#  'test_1142.JPEG',
#  'test_1143.JPEG',
#  'test_1144.JPEG',
#  'test_1145.JPEG',
#  'test_1146.JPEG',
#  'test_1147.JPEG',
#  'test_1148.JPEG',
#  'test_1149.JPEG',
#  'test_115.JPEG',
#  'test_1150.JPEG',
#  'test_1151.JPEG',
#  'test_1152.JPEG',
#  'test_1153.JPEG',
#  'test_1154.JPEG',
#  'test_1155.JPEG',
#  'test_1156.JPEG',
#  'test_1157.JPEG',
#  'test_1158.JPEG',
#  'test_1159.JPEG',
#  'test_116.JPEG',
#  'test_1160.JPEG',
#  'test_1161.JPEG',
#  'test_1162.JPEG',
#  'test_1163.JPEG',
#  'test_1164.JPEG',
#  'test_1165.JPEG',
#  'test_1166.JPEG',
#  'test_1167.JPEG',
#  'test_1168.JPEG',
#  'test_1169.JPEG',
#  'test_117.JPEG',
#  'test_1170.JPEG',
#  'test_1171.JPEG',
#  'test_1172.JPEG',
#  'test_1173.JPEG',
#  'test_1174.JPEG',
#  'test_1175.JPEG',
#  'test_1176.JPEG',
#  'test_1177.JPEG',
#  'test_1178.JPEG',
#  'test_1179.JPEG',
#  'test_118.JPEG',
#  'test_1180.JPEG',
#  'test_1181.JPEG',
#  'test_1182.JPEG',
#  'test_1183.JPEG',
#  'test_1184.JPEG',
#  'test_1185.JPEG',
#  'test_1186.JPEG',
#  'test_1187.JPEG',
#  'test_1188.JPEG',
#  'test_1189.JPEG',
#  'test_119.JPEG',
#  'test_1190.JPEG',
#  'test_1191.JPEG',
#  'test_1192.JPEG',
#  'test_1193.JPEG',
#  'test_1194.JPEG',
#  'test_1195.JPEG',
#  'test_1196.JPEG',
#  'test_1197.JPEG',
#  'test_1198.JPEG',
#  'test_1199.JPEG',
#  'test_12.JPEG',
#  'test_120.JPEG',
#  'test_1200.JPEG',
#  'test_1201.JPEG',
#  'test_1202.JPEG',
#  'test_1203.JPEG',
#  'test_1204.JPEG',
#  'test_1205.JPEG',
#  'test_1206.JPEG',
#  'test_1207.JPEG',
#  'test_1208.JPEG',
#  'test_1209.JPEG',
#  'test_121.JPEG',
#  'test_1210.JPEG',
#  'test_1211.JPEG',
#  'test_1212.JPEG',
#  'test_1213.JPEG',
#  'test_1214.JPEG',
#  'test_1215.JPEG',
#  'test_1216.JPEG',
#  'test_1217.JPEG',
#  'test_1218.JPEG',
#  'test_1219.JPEG',
#  'test_122.JPEG',
#  'test_1220.JPEG',
#  'test_1221.JPEG',
#  'test_1222.JPEG',
#  'test_1223.JPEG',
#  'test_1224.JPEG',
#  'test_1225.JPEG',
#  'test_1226.JPEG',
#  'test_1227.JPEG',
#  'test_1228.JPEG',
#  'test_1229.JPEG',
#  'test_123.JPEG',
#  'test_1230.JPEG',
#  'test_1231.JPEG',
#  'test_1232.JPEG',
#  'test_1233.JPEG',
#  'test_1234.JPEG',
#  'test_1235.JPEG',
#  'test_1236.JPEG',
#  'test_1237.JPEG',
#  'test_1238.JPEG',
#  'test_1239.JPEG',
#  'test_124.JPEG',
#  'test_1240.JPEG',
#  'test_1241.JPEG',
#  'test_1242.JPEG',
#  'test_1243.JPEG',
#  'test_1244.JPEG',
#  'test_1245.JPEG',
#  'test_1246.JPEG',
#  'test_1247.JPEG',
#  'test_1248.JPEG',
#  'test_1249.JPEG',
#  'test_125.JPEG',
#  'test_1250.JPEG',
#  'test_1251.JPEG',
#  'test_1252.JPEG',
#  'test_1253.JPEG',
#  'test_1254.JPEG',
#  'test_1255.JPEG',
#  'test_1256.JPEG',
#  'test_1257.JPEG',
#  'test_1258.JPEG',
#  'test_1259.JPEG',
#  'test_126.JPEG',
#  'test_1260.JPEG',
#  'test_1261.JPEG',
#  'test_1262.JPEG',
#  'test_1263.JPEG',
#  'test_1264.JPEG',
#  'test_1265.JPEG',
#  'test_1266.JPEG',
#  'test_1267.JPEG',
#  'test_1268.JPEG',
#  'test_1269.JPEG',
#  'test_127.JPEG',
#  'test_1270.JPEG',
#  'test_1271.JPEG',
#  'test_1272.JPEG',
#  'test_1273.JPEG',
#  'test_1274.JPEG',
#  'test_1275.JPEG',
#  'test_1276.JPEG',
#  'test_1277.JPEG',
#  'test_1278.JPEG',
#  'test_1279.JPEG',
#  'test_128.JPEG',
#  'test_1280.JPEG',
#  'test_1281.JPEG',
#  'test_1282.JPEG',
#  'test_1283.JPEG',
#  'test_1284.JPEG',
#  'test_1285.JPEG',
#  'test_1286.JPEG',
#  'test_1287.JPEG',
#  'test_1288.JPEG',
#  'test_1289.JPEG',
#  'test_129.JPEG',
#  'test_1290.JPEG',
#  'test_1291.JPEG',
#  'test_1292.JPEG',
#  'test_1293.JPEG',
#  'test_1294.JPEG',
#  'test_1295.JPEG',
#  'test_1296.JPEG',
#  'test_1297.JPEG',
#  'test_1298.JPEG',
#  'test_1299.JPEG',
#  'test_13.JPEG',
#  'test_130.JPEG',
#  'test_1300.JPEG',
#  'test_1301.JPEG',
#  'test_1302.JPEG',
#  'test_1303.JPEG',
#  'test_1304.JPEG',
#  'test_1305.JPEG',
#  'test_1306.JPEG',
#  'test_1307.JPEG',
#  'test_1308.JPEG',
#  'test_1309.JPEG',
#  'test_131.JPEG',
#  'test_1310.JPEG',
#  'test_1311.JPEG',
#  'test_1312.JPEG',
#  'test_1313.JPEG',
#  'test_1314.JPEG',
#  'test_1315.JPEG',
#  'test_1316.JPEG',
#  'test_1317.JPEG',
#  'test_1318.JPEG',
#  'test_1319.JPEG',
#  'test_132.JPEG',
#  'test_1320.JPEG',
#  'test_1321.JPEG',
#  'test_1322.JPEG',
#  'test_1323.JPEG',
#  'test_1324.JPEG',
#  'test_1325.JPEG',
#  'test_1326.JPEG',
#  'test_1327.JPEG',
#  'test_1328.JPEG',
#  'test_1329.JPEG',
#  'test_133.JPEG',
#  'test_1330.JPEG',
#  'test_1331.JPEG',
#  'test_1332.JPEG',
#  'test_1333.JPEG',
#  'test_1334.JPEG',
#  'test_1335.JPEG',
#  'test_1336.JPEG',
#  'test_1337.JPEG',
#  'test_1338.JPEG',
#  'test_1339.JPEG',
#  'test_134.JPEG',
#  'test_1340.JPEG',
#  'test_1341.JPEG',
#  'test_1342.JPEG',
#  'test_1343.JPEG',
#  'test_1344.JPEG',
#  'test_1345.JPEG',
#  'test_1346.JPEG',
#  'test_1347.JPEG',
#  'test_1348.JPEG',
#  'test_1349.JPEG',
#  'test_135.JPEG',
#  'test_1350.JPEG',
#  'test_1351.JPEG',
#  'test_1352.JPEG',
#  'test_1353.JPEG',
#  'test_1354.JPEG',
#  'test_1355.JPEG',
#  'test_1356.JPEG',
#  'test_1357.JPEG',
#  'test_1358.JPEG',
#  'test_1359.JPEG',
#  'test_136.JPEG',
#  'test_1360.JPEG',
#  'test_1361.JPEG',
#  'test_1362.JPEG',
#  'test_1363.JPEG',
#  'test_1364.JPEG',
#  'test_1365.JPEG',
#  'test_1366.JPEG',
#  'test_1367.JPEG',
#  'test_1368.JPEG',
#  'test_1369.JPEG',
#  'test_137.JPEG',
#  'test_1370.JPEG',
#  'test_1371.JPEG',
#  'test_1372.JPEG',
#  'test_1373.JPEG',
#  'test_1374.JPEG',
#  'test_1375.JPEG',
#  'test_1376.JPEG',
#  'test_1377.JPEG',
#  'test_1378.JPEG',
#  'test_1379.JPEG',
#  'test_138.JPEG',
#  'test_1380.JPEG',
#  'test_1381.JPEG',
#  'test_1382.JPEG',
#  'test_1383.JPEG',
#  'test_1384.JPEG',
#  'test_1385.JPEG',
#  'test_1386.JPEG',
#  'test_1387.JPEG',
#  'test_1388.JPEG',
#  'test_1389.JPEG',
#  'test_139.JPEG',
#  'test_1390.JPEG',
#  'test_1391.JPEG',
#  'test_1392.JPEG',
#  'test_1393.JPEG',
#  'test_1394.JPEG',
#  'test_1395.JPEG',
#  'test_1396.JPEG',
#  'test_1397.JPEG',
#  'test_1398.JPEG',
#  'test_1399.JPEG',
#  'test_14.JPEG',
#  'test_140.JPEG',
#  'test_1400.JPEG',
#  'test_1401.JPEG',
#  'test_1402.JPEG',
#  'test_1403.JPEG',
#  'test_1404.JPEG',
#  'test_1405.JPEG',
#  'test_1406.JPEG',
#  'test_1407.JPEG',
#  'test_1408.JPEG',
#  'test_1409.JPEG',
#  'test_141.JPEG',
#  'test_1410.JPEG',
#  'test_1411.JPEG',
#  'test_1412.JPEG',
#  'test_1413.JPEG',
#  'test_1414.JPEG',
#  'test_1415.JPEG',
#  'test_1416.JPEG',
#  'test_1417.JPEG',
#  'test_1418.JPEG',
#  'test_1419.JPEG',
#  'test_142.JPEG',
#  'test_1420.JPEG',
#  'test_1421.JPEG',
#  'test_1422.JPEG',
#  'test_1423.JPEG',
#  'test_1424.JPEG',
#  'test_1425.JPEG',
#  'test_1426.JPEG',
#  'test_1427.JPEG',
#  'test_1428.JPEG',
#  'test_1429.JPEG',
#  'test_143.JPEG',
#  'test_1430.JPEG',
#  'test_1431.JPEG',
#  'test_1432.JPEG',
#  'test_1433.JPEG',
#  'test_1434.JPEG',
#  'test_1435.JPEG',
#  'test_1436.JPEG',
#  'test_1437.JPEG',
#  'test_1438.JPEG',
#  'test_1439.JPEG',
#  'test_144.JPEG',
#  'test_1440.JPEG',
#  'test_1441.JPEG',
#  'test_1442.JPEG',
#  'test_1443.JPEG',
#  'test_1444.JPEG',
#  'test_1445.JPEG',
#  'test_1446.JPEG',
#  'test_1447.JPEG',
#  'test_1448.JPEG',
#  'test_1449.JPEG',
#  'test_145.JPEG',
#  'test_1450.JPEG',
#  'test_1451.JPEG',
#  'test_1452.JPEG',
#  'test_1453.JPEG',
#  'test_1454.JPEG',
#  'test_1455.JPEG',
#  'test_1456.JPEG',
#  'test_1457.JPEG',
#  'test_1458.JPEG',
#  'test_1459.JPEG',
#  'test_146.JPEG',
#  'test_1460.JPEG',
#  'test_1461.JPEG',
#  'test_1462.JPEG',
#  'test_1463.JPEG',
#  'test_1464.JPEG',
#  'test_1465.JPEG',
#  'test_1466.JPEG',
#  'test_1467.JPEG',
#  'test_1468.JPEG',
#  'test_1469.JPEG',
#  'test_147.JPEG',
#  'test_1470.JPEG',
#  'test_1471.JPEG',
#  'test_1472.JPEG',
#  'test_1473.JPEG',
#  'test_1474.JPEG',
#  'test_1475.JPEG',
#  'test_1476.JPEG',
#  'test_1477.JPEG',
#  'test_1478.JPEG',
#  'test_1479.JPEG',
#  'test_148.JPEG',
#  'test_1480.JPEG',
#  'test_1481.JPEG',
#  'test_1482.JPEG',
#  'test_1483.JPEG',
#  'test_1484.JPEG',
#  'test_1485.JPEG',
#  'test_1486.JPEG',
#  'test_1487.JPEG',
#  'test_1488.JPEG',
#  'test_1489.JPEG',
#  'test_149.JPEG',
#  'test_1490.JPEG',
#  'test_1491.JPEG',
#  'test_1492.JPEG',
#  'test_1493.JPEG',
#  'test_1494.JPEG',
#  'test_1495.JPEG',
#  'test_1496.JPEG',
#  'test_1497.JPEG',
#  'test_1498.JPEG',
#  'test_1499.JPEG',
#  'test_15.JPEG',
#  'test_150.JPEG',
#  'test_1500.JPEG',
#  'test_1501.JPEG',
#  'test_1502.JPEG',
#  'test_1503.JPEG',
#  'test_1504.JPEG',
#  'test_1505.JPEG',
#  'test_1506.JPEG',
#  'test_1507.JPEG',
#  'test_1508.JPEG',
#  'test_1509.JPEG',
#  'test_151.JPEG',
#  'test_1510.JPEG',
#  'test_1511.JPEG',
#  'test_1512.JPEG',
#  'test_1513.JPEG',
#  'test_1514.JPEG',
#  'test_1515.JPEG',
#  'test_1516.JPEG',
#  'test_1517.JPEG',
#  'test_1518.JPEG',
#  'test_1519.JPEG',
#  'test_152.JPEG',
#  'test_1520.JPEG',
#  'test_1521.JPEG',
#  'test_1522.JPEG',
#  'test_1523.JPEG',
#  'test_1524.JPEG',
#  'test_1525.JPEG',
#  'test_1526.JPEG',
#  'test_1527.JPEG',
#  'test_1528.JPEG',
#  'test_1529.JPEG',
#  'test_153.JPEG',
#  'test_1530.JPEG',
#  'test_1531.JPEG',
#  'test_1532.JPEG',
#  'test_1533.JPEG',
#  'test_1534.JPEG',
#  'test_1535.JPEG',
#  'test_1536.JPEG',
#  'test_1537.JPEG',
#  'test_1538.JPEG',
#  'test_1539.JPEG',
#  'test_154.JPEG',
#  'test_1540.JPEG',
#  'test_1541.JPEG',
#  'test_1542.JPEG',
#  'test_1543.JPEG',
#  'test_1544.JPEG',
#  'test_1545.JPEG',
#  'test_1546.JPEG',
#  'test_1547.JPEG',
#  'test_1548.JPEG',
#  'test_1549.JPEG',
#  'test_155.JPEG',
#  'test_1550.JPEG',
#  'test_1551.JPEG',
#  'test_1552.JPEG',
#  'test_1553.JPEG',
#  'test_1554.JPEG',
#  'test_1555.JPEG',
#  'test_1556.JPEG',
#  'test_1557.JPEG',
#  'test_1558.JPEG',
#  'test_1559.JPEG',
#  'test_156.JPEG',
#  'test_1560.JPEG',
#  'test_1561.JPEG',
#  'test_1562.JPEG',
#  'test_1563.JPEG',
#  'test_1564.JPEG',
#  'test_1565.JPEG',
#  'test_1566.JPEG',
#  'test_1567.JPEG',
#  'test_1568.JPEG',
#  'test_1569.JPEG',
#  'test_157.JPEG',
#  'test_1570.JPEG',
#  'test_1571.JPEG',
#  'test_1572.JPEG',
#  'test_1573.JPEG',
#  'test_1574.JPEG',
#  'test_1575.JPEG',
#  'test_1576.JPEG',
#  'test_1577.JPEG',
#  'test_1578.JPEG',
#  'test_1579.JPEG',
#  'test_158.JPEG',
#  'test_1580.JPEG',
#  'test_1581.JPEG',
#  'test_1582.JPEG',
#  'test_1583.JPEG',
#  'test_1584.JPEG',
#  'test_1585.JPEG',
#  'test_1586.JPEG',
#  'test_1587.JPEG',
#  'test_1588.JPEG',
#  'test_1589.JPEG',
#  'test_159.JPEG',
#  'test_1590.JPEG',
#  'test_1591.JPEG',
#  'test_1592.JPEG',
#  'test_1593.JPEG',
#  'test_1594.JPEG',
#  'test_1595.JPEG',
#  'test_1596.JPEG',
#  'test_1597.JPEG',
#  'test_1598.JPEG',
#  'test_1599.JPEG',
#  'test_16.JPEG',
#  'test_160.JPEG',
#  'test_1600.JPEG',
#  'test_1601.JPEG',
#  'test_1602.JPEG',
#  'test_1603.JPEG',
#  'test_1604.JPEG',
#  'test_1605.JPEG',
#  'test_1606.JPEG',
#  'test_1607.JPEG',
#  'test_1608.JPEG',
#  'test_1609.JPEG',
#  'test_161.JPEG',
#  'test_1610.JPEG',
#  'test_1611.JPEG',
#  'test_1612.JPEG',
#  'test_1613.JPEG',
#  'test_1614.JPEG',
#  'test_1615.JPEG',
#  'test_1616.JPEG',
#  'test_1617.JPEG',
#  'test_1618.JPEG',
#  'test_1619.JPEG',
#  'test_162.JPEG',
#  'test_1620.JPEG',
#  'test_1621.JPEG',
#  'test_1622.JPEG',
#  'test_1623.JPEG',
#  'test_1624.JPEG',
#  'test_1625.JPEG',
#  'test_1626.JPEG',
#  'test_1627.JPEG',
#  'test_1628.JPEG',
#  'test_1629.JPEG',
#  'test_163.JPEG',
#  'test_1630.JPEG',
#  'test_1631.JPEG',
#  'test_1632.JPEG',
#  'test_1633.JPEG',
#  'test_1634.JPEG',
#  'test_1635.JPEG',
#  'test_1636.JPEG',
#  'test_1637.JPEG',
#  'test_1638.JPEG',
#  'test_1639.JPEG',
#  'test_164.JPEG',
#  'test_1640.JPEG',
#  'test_1641.JPEG',
#  'test_1642.JPEG',
#  'test_1643.JPEG',
#  'test_1644.JPEG',
#  'test_1645.JPEG',
#  'test_1646.JPEG',
#  'test_1647.JPEG',
#  'test_1648.JPEG',
#  'test_1649.JPEG',
#  'test_165.JPEG',
#  'test_1650.JPEG',
#  'test_1651.JPEG',
#  'test_1652.JPEG',
#  'test_1653.JPEG',
#  'test_1654.JPEG',
#  'test_1655.JPEG',
#  'test_1656.JPEG',
#  'test_1657.JPEG',
#  'test_1658.JPEG',
#  'test_1659.JPEG',
#  'test_166.JPEG',
#  'test_1660.JPEG',
#  'test_1661.JPEG',
#  'test_1662.JPEG',
#  'test_1663.JPEG',
#  'test_1664.JPEG',
#  'test_1665.JPEG',
#  'test_1666.JPEG',
#  'test_1667.JPEG',
#  'test_1668.JPEG',
#  'test_1669.JPEG',
#  'test_167.JPEG',
#  'test_1670.JPEG',
#  'test_1671.JPEG',
#  'test_1672.JPEG',
#  'test_1673.JPEG',
#  'test_1674.JPEG',
#  'test_1675.JPEG',
#  'test_1676.JPEG',
#  'test_1677.JPEG',
#  'test_1678.JPEG',
#  'test_1679.JPEG',
#  'test_168.JPEG',
#  'test_1680.JPEG',
#  'test_1681.JPEG',
#  'test_1682.JPEG',
#  'test_1683.JPEG',
#  'test_1684.JPEG',
#  'test_1685.JPEG',
#  'test_1686.JPEG',
#  'test_1687.JPEG',
#  'test_1688.JPEG',
#  'test_1689.JPEG',
#  'test_169.JPEG',
#  'test_1690.JPEG',
#  'test_1691.JPEG',
#  'test_1692.JPEG',
#  'test_1693.JPEG',
#  'test_1694.JPEG',
#  'test_1695.JPEG',
#  'test_1696.JPEG',
#  'test_1697.JPEG',
#  'test_1698.JPEG',
#  'test_1699.JPEG',
#  'test_17.JPEG',
#  'test_170.JPEG',
#  'test_1700.JPEG',
#  'test_1701.JPEG',
#  'test_1702.JPEG',
#  'test_1703.JPEG',
#  'test_1704.JPEG',
#  'test_1705.JPEG',
#  'test_1706.JPEG',
#  'test_1707.JPEG',
#  'test_1708.JPEG',
#  'test_1709.JPEG',
#  'test_171.JPEG',
#  'test_1710.JPEG',
#  'test_1711.JPEG',
#  'test_1712.JPEG',
#  'test_1713.JPEG',
#  'test_1714.JPEG',
#  'test_1715.JPEG',
#  'test_1716.JPEG',
#  'test_1717.JPEG',
#  'test_1718.JPEG',
#  'test_1719.JPEG',
#  'test_172.JPEG',
#  'test_1720.JPEG',
#  'test_1721.JPEG',
#  'test_1722.JPEG',
#  'test_1723.JPEG',
#  'test_1724.JPEG',
#  'test_1725.JPEG',
#  'test_1726.JPEG',
#  'test_1727.JPEG',
#  'test_1728.JPEG',
#  'test_1729.JPEG',
#  'test_173.JPEG',
#  'test_1730.JPEG',
#  'test_1731.JPEG',
#  'test_1732.JPEG',
#  'test_1733.JPEG',
#  'test_1734.JPEG',
#  'test_1735.JPEG',
#  'test_1736.JPEG',
#  'test_1737.JPEG',
#  'test_1738.JPEG',
#  'test_1739.JPEG',
#  'test_174.JPEG',
#  'test_1740.JPEG',
#  'test_1741.JPEG',
#  'test_1742.JPEG',
#  'test_1743.JPEG',
#  'test_1744.JPEG',
#  'test_1745.JPEG',
#  'test_1746.JPEG',
#  'test_1747.JPEG',
#  'test_1748.JPEG',
#  'test_1749.JPEG',
#  'test_175.JPEG',
#  'test_1750.JPEG',
#  'test_1751.JPEG',
#  'test_1752.JPEG',
#  'test_1753.JPEG',
#  'test_1754.JPEG',
#  'test_1755.JPEG',
#  'test_1756.JPEG',
#  'test_1757.JPEG',
#  'test_1758.JPEG',
#  'test_1759.JPEG',
#  'test_176.JPEG',
#  'test_1760.JPEG',
#  'test_1761.JPEG',
#  'test_1762.JPEG',
#  'test_1763.JPEG',
#  'test_1764.JPEG',
#  'test_1765.JPEG',
#  'test_1766.JPEG',
#  'test_1767.JPEG',
#  'test_1768.JPEG',
#  'test_1769.JPEG',
#  'test_177.JPEG',
#  'test_1770.JPEG',
#  'test_1771.JPEG',
#  'test_1772.JPEG',
#  'test_1773.JPEG',
#  'test_1774.JPEG',
#  'test_1775.JPEG',
#  'test_1776.JPEG',
#  'test_1777.JPEG',
#  'test_1778.JPEG',
#  'test_1779.JPEG',
#  'test_178.JPEG',
#  'test_1780.JPEG',
#  'test_1781.JPEG',
#  'test_1782.JPEG',
#  'test_1783.JPEG',
#  'test_1784.JPEG',
#  'test_1785.JPEG',
#  'test_1786.JPEG',
#  'test_1787.JPEG',
#  'test_1788.JPEG',
#  'test_1789.JPEG',
#  'test_179.JPEG',
#  'test_1790.JPEG',
#  'test_1791.JPEG',
#  'test_1792.JPEG',
#  'test_1793.JPEG',
#  'test_1794.JPEG',
#  'test_1795.JPEG',
#  'test_1796.JPEG',
#  'test_1797.JPEG',
#  'test_1798.JPEG',
#  'test_1799.JPEG',
#  'test_18.JPEG',
#  'test_180.JPEG',
#  'test_1800.JPEG',
#  'test_1801.JPEG',
#  'test_1802.JPEG',
#  'test_1803.JPEG',
#  'test_1804.JPEG',
#  'test_1805.JPEG',
#  'test_1806.JPEG',
#  'test_1807.JPEG',
#  'test_1808.JPEG',
#  'test_1809.JPEG',
#  'test_181.JPEG',
#  'test_1810.JPEG',
#  'test_1811.JPEG',
#  'test_1812.JPEG',
#  'test_1813.JPEG',
#  'test_1814.JPEG',
#  'test_1815.JPEG',
#  'test_1816.JPEG',
#  'test_1817.JPEG',
#  'test_1818.JPEG',
#  'test_1819.JPEG',
#  'test_182.JPEG',
#  'test_1820.JPEG',
#  'test_1821.JPEG',
#  'test_1822.JPEG',
#  'test_1823.JPEG',
#  'test_1824.JPEG',
#  'test_1825.JPEG',
#  'test_1826.JPEG',
#  'test_1827.JPEG',
#  'test_1828.JPEG',
#  'test_1829.JPEG',
#  'test_183.JPEG',
#  'test_1830.JPEG',
#  'test_1831.JPEG',
#  'test_1832.JPEG',
#  'test_1833.JPEG',
#  'test_1834.JPEG',
#  'test_1835.JPEG',
#  'test_1836.JPEG',
#  'test_1837.JPEG',
#  'test_1838.JPEG',
#  'test_1839.JPEG',
#  'test_184.JPEG',
#  'test_1840.JPEG',
#  'test_1841.JPEG',
#  'test_1842.JPEG',
#  'test_1843.JPEG',
#  'test_1844.JPEG',
#  'test_1845.JPEG',
#  'test_1846.JPEG',
#  'test_1847.JPEG',
#  'test_1848.JPEG',
#  'test_1849.JPEG',
#  'test_185.JPEG',
#  'test_1850.JPEG',
#  'test_1851.JPEG',
#  'test_1852.JPEG',
#  'test_1853.JPEG',
#  'test_1854.JPEG',
#  'test_1855.JPEG',
#  'test_1856.JPEG',
#  'test_1857.JPEG',
#  'test_1858.JPEG',
#  'test_1859.JPEG',
#  'test_186.JPEG',
#  'test_1860.JPEG',
#  'test_1861.JPEG',
#  'test_1862.JPEG',
#  'test_1863.JPEG',
#  'test_1864.JPEG',
#  'test_1865.JPEG',
#  'test_1866.JPEG',
#  'test_1867.JPEG',
#  'test_1868.JPEG',
#  'test_1869.JPEG',
#  'test_187.JPEG',
#  'test_1870.JPEG',
#  'test_1871.JPEG',
#  'test_1872.JPEG',
#  'test_1873.JPEG',
#  'test_1874.JPEG',
#  'test_1875.JPEG',
#  'test_1876.JPEG',
#  'test_1877.JPEG',
#  'test_1878.JPEG',
#  'test_1879.JPEG',
#  'test_188.JPEG',
#  'test_1880.JPEG',
#  'test_1881.JPEG',
#  'test_1882.JPEG',
#  'test_1883.JPEG',
#  'test_1884.JPEG',
#  'test_1885.JPEG',
#  'test_1886.JPEG',
#  'test_1887.JPEG',
#  'test_1888.JPEG',
#  'test_1889.JPEG',
#  'test_189.JPEG',
#  'test_1890.JPEG',
#  'test_1891.JPEG',
#  'test_1892.JPEG',
#  'test_1893.JPEG',
#  'test_1894.JPEG',
#  'test_1895.JPEG',
#  'test_1896.JPEG',
#  'test_1897.JPEG',
#  'test_1898.JPEG',
#  ...]

# %%
dict =train_dataset.class_indices

key_list = list(dict.keys())
val_list = list(dict.values())

# As there is/are images which are in gray scale, so we can check only for color images or some sort of conversion can be done
for i in os.listdir('ImageNet/test/images'): # Here is containing file
    image = plt.imread(f'ImageNet/test/images/{i}')
    if len(image.shape) == 3:
        image = image.reshape(-1,image.shape[0], image.shape[1], 3) 
        '''
        a = model.predict(image, verbose=False).argmax()
        position = val_list.index(a)
        print(key_list[position])
        '''
        a = model.predict(image, verbose=False).argmax()
        if a == 1:
            print(i)
# Out:
# test_1001.JPEG
# test_1002.JPEG
# test_1008.JPEG
# test_1029.JPEG
# test_1046.JPEG
# test_1047.JPEG
# test_1048.JPEG
# test_1052.JPEG
# test_1053.JPEG
# test_1057.JPEG
# test_107.JPEG
# test_1076.JPEG
# test_1081.JPEG
# test_11.JPEG
# test_1111.JPEG
# test_1122.JPEG
# test_1149.JPEG
# test_1168.JPEG
# test_1178.JPEG
# test_1217.JPEG
# test_123.JPEG
# test_1231.JPEG
# test_1237.JPEG
# test_1238.JPEG
# test_1241.JPEG
# test_126.JPEG
# test_1265.JPEG
# test_1266.JPEG
# test_1273.JPEG
# test_1300.JPEG
# test_1309.JPEG
# test_1320.JPEG
# test_1323.JPEG
# test_1346.JPEG
# test_1391.JPEG
# test_1403.JPEG
# test_1417.JPEG
# test_1424.JPEG
# test_1426.JPEG
# test_1431.JPEG
# test_145.JPEG
# test_1454.JPEG
# test_1457.JPEG
# test_146.JPEG
# test_147.JPEG
# test_1478.JPEG
# test_1483.JPEG
# test_1533.JPEG
# test_1557.JPEG
# test_1559.JPEG
# test_1571.JPEG
# test_1574.JPEG
# test_1597.JPEG
# test_1603.JPEG
# test_1614.JPEG
# test_1625.JPEG
# test_1632.JPEG
# test_1648.JPEG
# test_1656.JPEG
# test_1665.JPEG
# test_1668.JPEG
# test_1679.JPEG
# test_168.JPEG
# test_1684.JPEG
# test_1690.JPEG
# test_1702.JPEG
# test_1707.JPEG
# test_1709.JPEG
# test_1723.JPEG
# test_1733.JPEG
# test_1744.JPEG
# test_1754.JPEG
# test_1768.JPEG
# test_1770.JPEG
# test_1773.JPEG
# test_1781.JPEG
# test_1786.JPEG
# test_1801.JPEG
# test_1826.JPEG
# test_1834.JPEG
# test_184.JPEG
# test_1846.JPEG
# test_1856.JPEG
# test_1861.JPEG
# test_1863.JPEG
# test_1879.JPEG
# test_1883.JPEG
# test_1915.JPEG
# test_1937.JPEG
# test_1941.JPEG
# test_1948.JPEG
# test_1964.JPEG
# test_1965.JPEG
# test_1970.JPEG
# test_1986.JPEG
# test_1993.JPEG
# test_2006.JPEG
# test_2023.JPEG
# test_2029.JPEG
# test_2046.JPEG
# test_205.JPEG
# test_206.JPEG
# test_208.JPEG
# test_2089.JPEG
# test_2090.JPEG
# test_2100.JPEG
# test_2110.JPEG
# test_2119.JPEG
# test_213.JPEG
# test_214.JPEG
# test_2146.JPEG
# test_2148.JPEG
# test_2155.JPEG
# test_2156.JPEG
# test_2182.JPEG
# test_2186.JPEG
# test_2194.JPEG
# test_2211.JPEG
# test_2223.JPEG
# test_2234.JPEG
# test_2241.JPEG
# test_2250.JPEG
# test_2253.JPEG
# test_2264.JPEG
# test_2269.JPEG
# test_2273.JPEG
# test_2279.JPEG
# test_228.JPEG
# test_2287.JPEG
# test_2292.JPEG
# test_230.JPEG
# test_2302.JPEG
# test_2306.JPEG
# test_2308.JPEG
# test_2354.JPEG
# test_2360.JPEG
# test_2362.JPEG
# test_2369.JPEG
# test_2377.JPEG
# test_2390.JPEG
# test_240.JPEG
# test_2407.JPEG
# test_2477.JPEG
# test_2480.JPEG
# test_2481.JPEG
# test_2485.JPEG
# test_2522.JPEG
# test_2523.JPEG
# test_2526.JPEG
# test_2543.JPEG
# test_2548.JPEG
# test_2561.JPEG
# test_2576.JPEG
# test_258.JPEG
# test_2582.JPEG
# test_2583.JPEG
# test_2608.JPEG
# test_2633.JPEG
# test_2636.JPEG
# test_2637.JPEG
# test_264.JPEG
# test_2652.JPEG
# test_2674.JPEG
# test_2682.JPEG
# test_2692.JPEG
# test_2693.JPEG
# test_270.JPEG
# test_2705.JPEG
# test_2727.JPEG
# test_2728.JPEG
# test_2740.JPEG
# test_2765.JPEG
# test_2769.JPEG
# test_2770.JPEG
# test_2772.JPEG
# test_2783.JPEG
# test_2787.JPEG
# test_2801.JPEG
# test_2807.JPEG
# test_2851.JPEG
# test_2852.JPEG
# test_2854.JPEG
# test_2859.JPEG
# test_2864.JPEG
# test_288.JPEG
# test_2890.JPEG
# test_2895.JPEG
# test_2897.JPEG
# test_2901.JPEG
# test_2908.JPEG
# test_2912.JPEG
# test_2916.JPEG
# test_294.JPEG
# test_295.JPEG
# test_2959.JPEG
# test_2977.JPEG
# test_2987.JPEG
# test_299.JPEG
# test_3018.JPEG
# test_302.JPEG
# test_3044.JPEG
# test_3050.JPEG
# test_3056.JPEG
# test_3071.JPEG
# test_3087.JPEG
# test_3095.JPEG
# test_3111.JPEG
# test_3113.JPEG
# test_3115.JPEG
# test_3120.JPEG
# test_313.JPEG
# test_3133.JPEG
# test_3137.JPEG
# test_314.JPEG
# test_3150.JPEG
# test_3162.JPEG
# test_3190.JPEG
# test_320.JPEG
# test_3202.JPEG
# test_3227.JPEG
# test_3228.JPEG
# test_323.JPEG
# test_3255.JPEG
# test_3256.JPEG
# test_3266.JPEG
# test_3273.JPEG
# test_3276.JPEG
# test_3287.JPEG
# test_3292.JPEG
# test_3310.JPEG
# test_3312.JPEG
# test_3320.JPEG
# test_3323.JPEG
# test_3324.JPEG
# test_3335.JPEG
# test_3338.JPEG
# test_3358.JPEG
# test_3364.JPEG
# test_3367.JPEG
# test_337.JPEG
# test_3381.JPEG
# test_3386.JPEG
# test_3390.JPEG
# test_3416.JPEG
# test_3424.JPEG
# test_3425.JPEG
# test_3434.JPEG
# test_3435.JPEG
# test_3437.JPEG
# test_3439.JPEG
# test_344.JPEG
# test_3468.JPEG
# test_3480.JPEG
# test_3483.JPEG
# test_3492.JPEG
# test_3501.JPEG
# test_3503.JPEG
# test_3519.JPEG
# test_3521.JPEG
# test_3525.JPEG
# test_3595.JPEG
# test_3611.JPEG
# test_3615.JPEG
# test_3619.JPEG
# test_3627.JPEG
# test_3633.JPEG
# test_3656.JPEG
# test_3664.JPEG
# test_3669.JPEG
# test_3679.JPEG
# test_3686.JPEG
# test_3690.JPEG
# test_3692.JPEG
# test_3702.JPEG
# test_3711.JPEG
# test_3719.JPEG
# test_3726.JPEG
# test_3735.JPEG
# test_3741.JPEG
# test_3747.JPEG
# test_3754.JPEG
# test_3759.JPEG
# test_3760.JPEG
# test_3777.JPEG
# test_3796.JPEG
# test_3798.JPEG
# test_3803.JPEG
# test_3811.JPEG
# test_3819.JPEG
# test_3821.JPEG
# test_3826.JPEG
# test_3838.JPEG
# test_3841.JPEG
# test_3848.JPEG
# test_386.JPEG
# test_3861.JPEG
# test_3865.JPEG
# test_3871.JPEG
# test_3879.JPEG
# test_3895.JPEG
# test_3903.JPEG
# test_3921.JPEG
# test_3927.JPEG
# test_394.JPEG
# test_3959.JPEG
# test_3960.JPEG
# test_3976.JPEG
# test_4005.JPEG
# test_4009.JPEG
# test_4030.JPEG
# test_4034.JPEG
# test_4045.JPEG
# test_4053.JPEG
# test_4057.JPEG
# test_4059.JPEG
# test_4062.JPEG
# test_4070.JPEG
# test_4075.JPEG
# test_4078.JPEG
# test_4087.JPEG
# test_4127.JPEG
# test_4128.JPEG
# test_4138.JPEG
# test_4139.JPEG
# test_4140.JPEG
# test_4155.JPEG
# test_417.JPEG
# test_4209.JPEG
# test_4248.JPEG
# test_4251.JPEG
# test_4269.JPEG
# test_4272.JPEG
# test_4278.JPEG
# test_4353.JPEG
# test_4365.JPEG
# test_4370.JPEG
# test_4387.JPEG
# test_4389.JPEG
# test_4396.JPEG
# test_440.JPEG
# test_4411.JPEG
# test_4420.JPEG
# test_4427.JPEG
# test_4431.JPEG
# test_4435.JPEG
# test_4441.JPEG
# test_4457.JPEG
# test_4461.JPEG
# test_4467.JPEG
# test_447.JPEG
# test_4475.JPEG
# test_4500.JPEG
# test_4511.JPEG
# test_4514.JPEG
# test_4515.JPEG
# test_4533.JPEG
# test_4542.JPEG
# test_4553.JPEG
# test_4556.JPEG
# test_4557.JPEG
# test_4562.JPEG
# test_458.JPEG
# test_4602.JPEG
# test_4603.JPEG
# test_4606.JPEG
# test_4611.JPEG
# test_4633.JPEG
# test_4635.JPEG
# test_4661.JPEG
# test_4695.JPEG
# test_4712.JPEG
# test_4714.JPEG
# test_4733.JPEG
# test_4735.JPEG
# test_4750.JPEG
# test_4766.JPEG
# test_4770.JPEG
# test_4776.JPEG
# test_4778.JPEG
# test_4784.JPEG
# test_4785.JPEG
# test_4788.JPEG
# test_4795.JPEG
# test_48.JPEG
# test_4802.JPEG
# test_4811.JPEG
# test_4814.JPEG
# test_4815.JPEG
# test_482.JPEG
# test_4821.JPEG
# test_4837.JPEG
# test_4842.JPEG
# test_4844.JPEG
# test_4866.JPEG
# test_4867.JPEG
# test_4878.JPEG
# test_4898.JPEG
# test_4899.JPEG
# test_4905.JPEG
# test_4912.JPEG
# test_4923.JPEG
# test_4931.JPEG
# test_494.JPEG
# test_4972.JPEG
# test_4975.JPEG
# test_4984.JPEG
# test_499.JPEG
# test_4994.JPEG
# test_5037.JPEG
# test_5046.JPEG
# test_5056.JPEG
# test_5058.JPEG
# test_5070.JPEG
# test_5072.JPEG
# test_5083.JPEG
# test_5093.JPEG
# test_5097.JPEG
# test_5136.JPEG
# test_5142.JPEG
# test_5144.JPEG
# test_516.JPEG
# test_5160.JPEG
# test_517.JPEG
# test_5179.JPEG
# test_5181.JPEG
# test_5250.JPEG
# test_5253.JPEG
# test_5277.JPEG
# test_5280.JPEG
# test_5285.JPEG
# test_529.JPEG
# test_5292.JPEG
# test_5297.JPEG
# test_5307.JPEG
# test_5317.JPEG
# test_532.JPEG
# test_5337.JPEG
# test_5341.JPEG
# test_5349.JPEG
# test_5356.JPEG
# test_5369.JPEG
# test_5382.JPEG
# test_5396.JPEG
# test_5415.JPEG
# test_542.JPEG
# test_5428.JPEG
# test_5434.JPEG
# test_5448.JPEG
# test_5475.JPEG
# test_5485.JPEG
# test_549.JPEG
# test_5491.JPEG
# test_55.JPEG
# test_5501.JPEG
# test_5522.JPEG
# test_5525.JPEG
# test_5526.JPEG
# test_5549.JPEG
# test_5574.JPEG
# test_5609.JPEG
# test_5625.JPEG
# test_5629.JPEG
# test_564.JPEG
# test_567.JPEG
# test_5682.JPEG
# test_5720.JPEG
# test_5722.JPEG
# test_5728.JPEG
# test_5740.JPEG
# test_5744.JPEG
# test_5745.JPEG
# test_5755.JPEG
# test_5756.JPEG
# test_5759.JPEG
# test_5760.JPEG
# test_5779.JPEG
# test_5786.JPEG
# test_5796.JPEG
# test_5803.JPEG
# test_5819.JPEG
# test_5825.JPEG
# test_5843.JPEG
# test_5845.JPEG
# test_5854.JPEG
# test_5864.JPEG
# test_5866.JPEG
# test_5867.JPEG
# test_5871.JPEG
# test_5888.JPEG
# test_5890.JPEG
# test_5894.JPEG
# test_5905.JPEG
# test_5916.JPEG
# test_5918.JPEG
# test_5946.JPEG
# test_5973.JPEG
# test_5977.JPEG
# test_6010.JPEG
# test_6020.JPEG
# test_6027.JPEG
# test_6048.JPEG
# test_6051.JPEG
# test_6072.JPEG
# test_6112.JPEG
# test_6123.JPEG
# test_6141.JPEG
# test_6151.JPEG
# test_6159.JPEG
# test_6182.JPEG
# test_6185.JPEG
# test_6186.JPEG
# test_6189.JPEG
# test_6201.JPEG
# test_621.JPEG
# test_6217.JPEG
# test_6220.JPEG
# test_6221.JPEG
# test_6223.JPEG
# test_6231.JPEG
# test_6253.JPEG
# test_6256.JPEG
# test_6289.JPEG
# test_6292.JPEG
# test_6295.JPEG
# test_6297.JPEG
# test_6307.JPEG
# test_6317.JPEG
# test_6327.JPEG
# test_633.JPEG
# test_6334.JPEG
# test_6339.JPEG
# test_6344.JPEG
# test_635.JPEG
# test_639.JPEG
# test_6399.JPEG
# test_6401.JPEG
# test_6413.JPEG
# test_643.JPEG
# test_6431.JPEG
# test_644.JPEG
# test_6493.JPEG
# test_6497.JPEG
# test_6505.JPEG
# test_655.JPEG
# test_656.JPEG
# test_6560.JPEG
# test_6562.JPEG
# test_6569.JPEG
# test_6574.JPEG
# test_6584.JPEG
# test_6605.JPEG
# test_6621.JPEG
# test_6634.JPEG
# test_6640.JPEG
# test_6646.JPEG
# test_6660.JPEG
# test_6663.JPEG
# test_6672.JPEG
# test_6696.JPEG
# test_6702.JPEG
# test_6708.JPEG
# test_672.JPEG
# test_6735.JPEG
# test_6736.JPEG
# test_6741.JPEG
# test_6747.JPEG
# test_6752.JPEG
# test_6763.JPEG
# test_6767.JPEG
# test_6786.JPEG
# test_6797.JPEG
# test_6803.JPEG
# test_6806.JPEG
# test_6810.JPEG
# test_6813.JPEG
# test_6819.JPEG
# test_6823.JPEG
# test_6833.JPEG
# test_6841.JPEG
# test_6851.JPEG
# test_6861.JPEG
# test_6864.JPEG
# test_6866.JPEG
# test_687.JPEG
# test_6880.JPEG
# test_6886.JPEG
# test_6888.JPEG
# test_6901.JPEG
# test_6903.JPEG
# test_6913.JPEG
# test_692.JPEG
# test_6926.JPEG
# test_6927.JPEG
# test_6948.JPEG
# test_6953.JPEG
# test_6957.JPEG
# test_6969.JPEG
# test_6980.JPEG
# test_6989.JPEG
# test_6992.JPEG
# test_6999.JPEG
# test_7027.JPEG
# test_7028.JPEG
# test_7036.JPEG
# test_7038.JPEG
# test_7042.JPEG
# test_7046.JPEG
# test_7091.JPEG
# test_7094.JPEG
# test_7104.JPEG
# test_7120.JPEG
# test_7121.JPEG
# test_7138.JPEG
# test_7139.JPEG
# test_7157.JPEG
# test_7174.JPEG
# test_7177.JPEG
# test_7182.JPEG
# test_7185.JPEG
# test_7205.JPEG
# test_7211.JPEG
# test_7216.JPEG
# test_7231.JPEG
# test_7241.JPEG
# test_7245.JPEG
# test_7272.JPEG
# test_7280.JPEG
# test_7303.JPEG
# test_7319.JPEG
# test_7321.JPEG
# test_7359.JPEG
# test_7365.JPEG
# test_7374.JPEG
# test_7379.JPEG
# test_7385.JPEG
# test_7399.JPEG
# test_740.JPEG
# test_7417.JPEG
# test_7427.JPEG
# test_7428.JPEG
# test_7431.JPEG
# test_7432.JPEG
# test_7469.JPEG
# test_7484.JPEG
# test_7493.JPEG
# test_7498.JPEG
# test_7518.JPEG
# test_7530.JPEG
# test_7540.JPEG
# test_7551.JPEG
# test_7565.JPEG
# test_7576.JPEG
# test_7577.JPEG
# test_7578.JPEG
# test_7587.JPEG
# test_7596.JPEG
# test_761.JPEG
# test_7618.JPEG
# test_7627.JPEG
# test_7649.JPEG
# test_7667.JPEG
# test_7688.JPEG
# test_7689.JPEG
# test_7702.JPEG
# test_7703.JPEG
# test_7730.JPEG
# test_7737.JPEG
# test_7747.JPEG
# test_775.JPEG
# test_7752.JPEG
# test_7755.JPEG
# test_7764.JPEG
# test_7771.JPEG
# test_778.JPEG
# test_7807.JPEG
# test_7837.JPEG
# test_7840.JPEG
# test_7847.JPEG
# test_7852.JPEG
# test_7857.JPEG
# test_7858.JPEG
# test_7861.JPEG
# test_7869.JPEG
# test_787.JPEG
# test_7870.JPEG
# test_7876.JPEG
# test_7880.JPEG
# test_7882.JPEG
# test_7898.JPEG
# test_7908.JPEG
# test_7953.JPEG
# test_7959.JPEG
# test_7961.JPEG
# test_7966.JPEG
# test_7967.JPEG
# test_7980.JPEG
# test_7995.JPEG
# test_800.JPEG
# test_8018.JPEG
# test_8026.JPEG
# test_8027.JPEG
# test_8032.JPEG
# test_8045.JPEG
# test_8049.JPEG
# test_805.JPEG
# test_8059.JPEG
# test_8085.JPEG
# test_8089.JPEG
# test_809.JPEG
# test_811.JPEG
# test_8112.JPEG
# test_8124.JPEG
# test_8134.JPEG
# test_8145.JPEG
# test_8156.JPEG
# test_8163.JPEG
# test_8188.JPEG
# test_8211.JPEG
# test_8222.JPEG
# test_8236.JPEG
# test_8238.JPEG
# test_8258.JPEG
# test_8262.JPEG
# test_8271.JPEG
# test_8275.JPEG
# test_8278.JPEG
# test_8279.JPEG
# test_8281.JPEG
# test_8289.JPEG
# test_8308.JPEG
# test_8313.JPEG
# test_8316.JPEG
# test_8339.JPEG
# test_8346.JPEG
# test_8354.JPEG
# test_8379.JPEG
# test_8384.JPEG
# test_8390.JPEG
# test_840.JPEG
# test_8406.JPEG
# test_8420.JPEG
# test_8425.JPEG
# test_8430.JPEG
# test_8431.JPEG
# test_8436.JPEG
# test_8439.JPEG
# test_8440.JPEG
# test_850.JPEG
# test_8513.JPEG
# test_8515.JPEG
# test_8516.JPEG
# test_852.JPEG
# test_8529.JPEG
# test_8531.JPEG
# test_8538.JPEG
# test_8546.JPEG
# test_8552.JPEG
# test_8556.JPEG
# test_8573.JPEG
# test_8580.JPEG
# test_8590.JPEG
# test_8608.JPEG
# test_8624.JPEG
# test_8633.JPEG
# test_8635.JPEG
# test_867.JPEG
# test_8670.JPEG
# test_8672.JPEG
# test_8679.JPEG
# test_8687.JPEG
# test_8695.JPEG
# test_8696.JPEG
# test_8702.JPEG
# test_8708.JPEG
# test_871.JPEG
# test_8728.JPEG
# test_8783.JPEG
# test_8784.JPEG
# test_8800.JPEG
# test_8815.JPEG
# test_8824.JPEG
# test_8855.JPEG
# test_8859.JPEG
# test_8869.JPEG
# test_889.JPEG
# test_8904.JPEG
# test_8908.JPEG
# test_8921.JPEG
# test_8923.JPEG
# test_8930.JPEG
# test_8933.JPEG
# test_8949.JPEG
# test_8951.JPEG
# test_8961.JPEG
# test_8962.JPEG
# test_8972.JPEG
# test_8986.JPEG
# test_8993.JPEG
# test_9020.JPEG
# test_9021.JPEG
# test_9023.JPEG
# test_9025.JPEG
# test_9028.JPEG
# test_9037.JPEG
# test_9045.JPEG
# test_906.JPEG
# test_9073.JPEG
# test_9079.JPEG
# test_9098.JPEG
# test_9107.JPEG
# test_9117.JPEG
# test_9131.JPEG
# test_9140.JPEG
# test_9141.JPEG
# test_9142.JPEG
# test_9143.JPEG
# test_9160.JPEG
# test_917.JPEG
# test_9174.JPEG
# test_918.JPEG
# test_9188.JPEG
# test_9198.JPEG
# test_9199.JPEG
# test_9203.JPEG
# test_9205.JPEG
# test_9211.JPEG
# test_9217.JPEG
# test_9267.JPEG
# test_9278.JPEG
# test_9291.JPEG
# test_9319.JPEG
# test_9335.JPEG
# test_9378.JPEG
# test_9379.JPEG
# test_9389.JPEG
# test_9393.JPEG
# test_9402.JPEG
# test_9415.JPEG
# test_9422.JPEG
# test_9432.JPEG
# test_9443.JPEG
# test_9450.JPEG
# test_9456.JPEG
