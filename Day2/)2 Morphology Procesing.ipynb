# %%
# !pip install morfessor

# %%
# !pip install pyglot pyICU
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/262.4 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/262.4 kB ? eta -:--:--
#      ---------------- --------------------- 112.6/262.4 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  256.0/262.4 kB 1.8 MB/s eta 0:00:01
#      -------------------------------------- 262.4/262.4 kB 1.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       (running 'icu-config --version')
#       (running 'pkg-config --modversion icu-i18n')
# ...

# %%
# !pip install pyICU
# Out:
# ...
#   Using cached PyICU-2.13.1.tar.gz (262 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [66 lines of output]
#       (running 'icu-config --version')
#       (running 'pkg-config --modversion icu-i18n')
#       Traceback (most recent call last):
#         File "<string>", line 89, in <module>
#         File "<frozen os>", line 679, in __getitem__
#       KeyError: 'ICU_VERSION'
#
#       During handling of the above exception, another exception occurred:
#
#       Traceback (most recent call last):
#         File "<string>", line 92, in <module>
#         File "<string>", line 19, in check_output
# ...
